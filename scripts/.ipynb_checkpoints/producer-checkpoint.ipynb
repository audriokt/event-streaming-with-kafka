# %%
# !pip install confluent_kafka
# Out:
# Collecting confluent_kafka
#   Downloading confluent_kafka-2.13.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (32 kB)
# Downloading confluent_kafka-2.13.2-cp311-cp311-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 8.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: confluent_kafka
# Successfully installed confluent_kafka-2.13.2

# %%
import json, time, random
from confluent_kafka import Producer

# Konfigurasi Kafka producer
producer_config = {
    'bootstrap.servers':'kafka:9092'
}
producer = Producer(producer_config)

# Daftar user sebagai key
users = ["user123", "user456", "user789"]

# Callback untuk monitoring delivery
def delivery_report(err,msg):
    if err:
        print(f'Delivery failed: {err}')
    else:
        print(f"Delivered: {msg.value().decode('utf-8')}")
        print(dir(msg))
        print(f'Delivered to {msg.value()} : partition {msg.partition()} : at offset {msg.offset()}')

i = 0
# Loop kirim 10 event
while i < 10:
    key = random.choice(users)
    value = json.dumps({
        "event": "login",
        "user": key,
        "timestamp": time.time()    
    }).encode('utf-8')
    try: 
        producer.produce( 
            topic="events_topic", 
            key=key, value=value, 
            callback=delivery_report 
        ) 
        producer.flush() 
    except Exception as e: 
        print(f"Failed to produce message: {e}")
    i+=1
    time.sleep(5)
# Out:
# Delivered: {"event": "login", "user": "user456", "timestamp": 1772635662.5592806}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user456", "timestamp": 1772635662.5592806}' : partition 0 : at offset 0
# Delivered: {"event": "login", "user": "user123", "timestamp": 1772635667.6019304}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user123", "timestamp": 1772635667.6019304}' : partition 0 : at offset 1
# Delivered: {"event": "login", "user": "user123", "timestamp": 1772635672.6059916}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user123", "timestamp": 1772635672.6059916}' : partition 0 : at offset 2
# Delivered: {"event": "login", "user": "user456", "timestamp": 1772635677.6099377}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user456", "timestamp": 1772635677.6099377}' : partition 0 : at offset 3
# Delivered: {"event": "login", "user": "user789", "timestamp": 1772635682.6149633}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user789", "timestamp": 1772635682.6149633}' : partition 0 : at offset 4
# Delivered: {"event": "login", "user": "user123", "timestamp": 1772635687.6179934}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user123", "timestamp": 1772635687.6179934}' : partition 0 : at offset 5
# Delivered: {"event": "login", "user": "user789", "timestamp": 1772635692.6227589}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user789", "timestamp": 1772635692.6227589}' : partition 0 : at offset 6
# Delivered: {"event": "login", "user": "user789", "timestamp": 1772635697.6257007}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user789", "timestamp": 1772635697.6257007}' : partition 0 : at offset 7
# Delivered: {"event": "login", "user": "user123", "timestamp": 1772635702.6297228}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user123", "timestamp": 1772635702.6297228}' : partition 0 : at offset 8
# Delivered: {"event": "login", "user": "user123", "timestamp": 1772635707.6336899}
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'error', 'headers', 'key', 'latency', 'leader_epoch', 'offset', 'partition', 'set_error', 'set_headers', 'set_key', 'set_topic', 'set_value', 'timestamp', 'topic', 'value']
# Delivered to b'{"event": "login", "user": "user123", "timestamp": 1772635707.6336899}' : partition 0 : at offset 9

# %%
#ngecek list topic yang tersedia
docker exec -it kafka kafka-topics --list --bootstrap-server localhost:9092

#
docker exec -it kafka kafka-topics --bootstrap-server localhost:9092 --describe --topic orders

docker exec -it kafka kafka-console-consumer --bootstrap-server localhost:9092 localhost:9092 --topic orders --from-beginning
